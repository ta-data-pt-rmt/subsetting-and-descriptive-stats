# %% [markdown]
# # Subsetting and Descriptive Stats
#
# ## Before your start:
#    - Remember that you just need to do one of the challenges.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in IronHack's database.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly: enjoy the process!
#
# #### Import all the necessary libraries here:

# %%
# import libraries here

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # [ONLY ONE MANDATORY] Challenge 1
# #### In this challenge we will use the `Temp_States`  dataset.
#
# #### First import it into a dataframe called `temp`.

# %%
# your code here

temp_df = pd.read_csv("Temp_States.csv")

# %% [markdown]
# #### Print `temp`.

# %%
# your code here
display(temp_df)
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the *temp* dataframe. What types of data do we have? Comment your result.

# %%
# your code here

temp_df.dtypes
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %%
# We have 2 columns with object and text information, and 1 columns with float numbers

# %% [markdown]
# #### Select the rows where state is New York.

# %%
# your code here

display(temp_df[temp_df['State'] == 'New York'])
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average temperature of cities in New York?

# %%
# your code here

print("NY cities avg temp: ", ((temp_df[temp_df['State'] == 'New York'])['Temperature']).mean())
# Out:
# NY cities avg temp:  10.74074074074074

# %% [markdown]
# #### Which states and cities have a temperature above 15 degrees Celsius?

# %%
# your code here

display(temp_df[temp_df['Temperature'] > 15])
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degrees Celsius.

# %%
# your code here

df = (temp_df[temp_df['Temperature'] > 15])
df.drop('State', inplace=True, axis=1)
df
# Out:
# C:\Users\fcavanagh\AppData\Local\Temp\ipykernel_15136\148356635.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('State', inplace=True, axis=1)
#        City  Temperature
# 0       NYC    19.444444
# 3  Hartford    17.222222
# 5    Treton    22.222222
# 6    Newark    20.000000

# %% [markdown]
# #### Which cities have a temperature above 15 degrees Celcius and below 20 degrees Celsius?
#
# **Hint**: First, write the condition. Then, select the rows.

# %%
# your code here

df1 = (temp_df[(temp_df['Temperature'] > 15) & (temp_df['Temperature'] < 20)])
df1.drop('State', inplace=True, axis=1)
df1
# Out:
# C:\Users\fcavanagh\AppData\Local\Temp\ipykernel_15136\1337825620.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop('State', inplace=True, axis=1)
#        City  Temperature
# 0       NYC    19.444444
# 3  Hartford    17.222222

# %% [markdown]
# #### Find the mean and standard deviation of the temperature of each state.

# %%
# your code here

#1st Idenity how many states are in the df
print(temp_df['State'].value_counts())

# Create df x state and change column name
NY = ((temp_df[temp_df['State'] == 'New York']).rename(columns={'Temperature': 'NY'}))
CN = ((temp_df[temp_df['State'] == 'Connecticut']).rename(columns={'Temperature': 'CN'}))
NJ = ((temp_df[temp_df['State'] == 'New Jersey']).rename(columns={'Temperature': 'NJ'}))

# merge the 3 df's describe function and compare them
NY_CN = (pd.merge(NY.describe(), CN.describe(), left_index=True, right_index=True, suffixes=('', '2')))
NY_CN_NJ = (pd.merge(NY_CN, NJ.describe(), left_index=True, right_index=True, suffixes=('', '2')))
NY_CN_NJ
# Out:
# New York       3
# Connecticut    2
# New Jersey     2
# Name: State, dtype: int64
#               NY         CN         NJ
# count   3.000000   2.000000   2.000000
# mean   10.740741  15.833333  21.111111
# std     8.133404   1.964186   1.571348
# min     3.333333  14.444444  20.000000
# 25%     6.388889  15.138889  20.555556
# 50%     9.444444  15.833333  21.111111
# 75%    14.444444  16.527778  21.666667
# max    19.444444  17.222222  22.222222

# %% [markdown]
# # [ONLY ONE MANDATORY]  Challenge 2

# %% [markdown]
# #### Load the `employees` dataset into a dataframe. Call the dataframe `employees`.

# %%
# your code here

employees_df = pd.read_csv("Employee.csv")
employees_df
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Explore the data types of the `employees` dataframe. Comment your results.

# %%
# your code here

employees_df.dtypes
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %%
# We have 5 columns with object and text information, and 2 columns with int numbers

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your code here

print('Company avg salary: ', employees_df['Salary'].mean())
# Out:
# Company avg salary:  48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
# your code here

print('Company highest salary: ', employees_df['Salary'].max())
# Out:
# Company highest salary:  70

# %% [markdown]
# #### What's the lowest salary?

# %%
# your code here

print('Company lowest salary: ', employees_df['Salary'].min())
# Out:
# Company lowest salary:  30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your code here

display(employees_df[employees_df['Salary'] == (employees_df['Salary'].min())])
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find all the information about an employee called David.

# %%
# your code here

display(employees_df[employees_df['Name'] == 'David'])
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you return only David's salary?

# %%
# your code here

print("David salary is: ", employees_df.loc[employees_df['Name'] == 'David', 'Salary'].iloc[0])
# Out:
# David salary is:  30

# %% [markdown]
# #### Print all the rows where job title is associate.

# %%
# your code here

display(employees_df[employees_df['Title'] == 'associate'])
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe.
# **Tip**: There are 2 ways to do it. Do it both ways.

# %%
# Method 1
# your code here

display(employees_df.iloc[:3])
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# Method 2
# your code here

employees_df.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees whose title is associate and whose salary is above 55.

# %%
# your code here

display(employees_df[(employees_df['Title'] == 'associate') & (employees_df['Salary'] > 55)])
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees by number of years of employment. What are the average salaries in each group?

# %%
# your code here

display(employees_df.groupby(['Years']).agg({'Salary':'mean'}).reset_index())
# Out:
#    Years     Salary
# 0      1  35.000000
# 1      2  38.333333
# 2      3  55.000000
# 3      4  35.000000
# 4      7  60.000000
# 5      8  70.000000

# %% [markdown]
# ####  What is the average salary per title?

# %%
# your code here

display(employees_df.groupby(['Title']).agg({'Salary':'mean'}))
# Out:
#               Salary
# Title
# VP         70.000000
# analyst    32.500000
# associate  56.666667

# %% [markdown]
# ####  Find the salary quartiles.

# %%
# your code here

print("0% QUART-", np.quantile(employees_df['Salary'], 0))
print("25% QUART-", np.quantile(employees_df['Salary'], .25))
print("50% QUART-", np.quantile(employees_df['Salary'], .5))
print("75% QUART-", np.quantile(employees_df['Salary'], .75))
print("100% QUART-", np.quantile(employees_df['Salary'], 1))
# Out:
# 0% QUART- 30
# 25% QUART- 35.0
# 50% QUART- 55.0
# 75% QUART- 60.0
# 100% QUART- 70

# %% [markdown]
# #### Is the mean salary different per gender?

# %%
# your code here

display(employees_df.groupby(['Gender']).agg({'Salary':'mean'}).reset_index())
# Out:
#   Gender  Salary
# 0      F    47.5
# 1      M    50.0

# %% [markdown]
# #### Find the minimum, mean and maximum of all numeric columns for each company department.

# %%
# your code here

df_min = (employees_df.groupby(['Department']).agg({'Salary':'min','Years':'min'})).rename(columns={'Salary': 'S_min','Years':'Y_min'})
df_max = (employees_df.groupby(['Department']).agg({'Salary':'max','Years':'max'})).rename(columns={'Salary': 'S_max','Years':'Y_max'})
df_mean = (employees_df.groupby(['Department']).agg({'Salary':'mean','Years':'mean'})).rename(columns={'Salary': 'S_mean','Years':'Y_mean'})

min_mean = (pd.merge(df_min, df_mean, left_index=True, right_index=True, suffixes=('', '2')))
min_mean_max = (pd.merge(min_mean, df_max, left_index=True, right_index=True, suffixes=('', '2')).reset_index())
min_mean_max
# Out:
#   Department  S_min  Y_min  S_mean    Y_mean  S_max  Y_max
# 0         HR     30      2   45.00  4.666667     70      8
# 1         IT     30      1   48.75  4.500000     70      8
# 2      Sales     55      2   55.00  2.500000     55      3

# %% [markdown]
# #### Bonus Question:  for each department, compute the difference between the maximum and the minimum salary.
# **Hint**: try using `agg` or `apply` combined with `lambda` functions.

# %%
# your code here

def net(df):
    df_min1 = (df.groupby(['Department']).agg({'Salary':'min'})).rename(columns={'Salary': 'S_min'})
    df_max1 = (df.groupby(['Department']).agg({'Salary':'max'})).rename(columns={'Salary': 'S_max'})
    min_max1 = (pd.merge(df_max1, df_min1, left_index=True, right_index=True, suffixes=('', '2')).reset_index())
    min_max1['Net'] = min_max1['S_max'] - min_max1['S_min']
    return min_max1

net(employees_df)
# Out:
#   Department  S_max  S_min  Net
# 0         HR     70     30   40
# 1         IT     70     30   40
# 2      Sales     55     55    0

# %% [markdown]
# # [ONLY ONE MANDATORY] Challenge 3
# #### Open the `Orders` dataset. Name your dataset `orders`.

# %%
# your code here

orders_df = pd.read_csv("Orders.csv")
orders_df
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0                0     536365    85123A  2010     12    3     8
# 1                1     536365     71053  2010     12    3     8
# 2                2     536365    84406B  2010     12    3     8
# 3                3     536365    84029G  2010     12    3     8
# 4                4     536365    84029E  2010     12    3     8
# ...            ...        ...       ...   ...    ...  ...   ...
# 397919      541904     581587     22613  2011     12    5    12
# 397920      541905     581587     22899  2011     12    5    12
# 397921      541906     581587     23254  2011     12    5    12
# 397922      541907     581587     23255  2011     12    5    12
# 397923      541908     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6  2010-12-01 08:26:00
# ...

# %% [markdown]
# #### Explore your dataset by looking at the data types and summary statistics. Comment your results.

# %%
# your code here

print(orders_df.dtypes)
display(orders_df.describe())
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
# ...

# %%
# its a very numerical df (mani float and int columns)

# %% [markdown]
# ####  What is the average purchase price?

# %%
# your code here

orders_df['UnitPrice'].mean()
# Out:
# 3.116174480549152

# %% [markdown]
# #### What are the highest and lowest purchase prices?

# %%
# your code here

print("Price max:", orders_df['UnitPrice'].max())
print("Price min:", orders_df['UnitPrice'].min())
# Out:
# Price max: 8142.75
# Price min: 0.0

# %% [markdown]
# #### Select all the customers from Spain.
# **Hint**: Remember that you are not asked to find orders from Spain but customers. A customer might have more than one order associated.

# %%
# your code here

# first we filter and storage spain df
spain = (orders_df[orders_df['Country'] == 'Spain']) 

# once filter spain as cointry, count the customerID column
pd.DataFrame(spain['CustomerID'].unique(),columns=['Spanish Customer'])
# Out:
#     Spanish Customer
# 0              12557
# 1              17097
# 2              12540
# 3              12551
# 4              12484
# 5              12539
# 6              12510
# 7              12421
# 8              12502
# 9              12462
# 10             12507
# 11             12541
# 12             12547
# 13             12597
# 14             12545
# 15             12596
# 16             12354
# 17             12417
# 18             12455
# 19             12450
# 20             12548
# 21             12556
# 22             12550
# 23             12546
# 24             12454
# 25             12448
# 26             12544
# 27             12538
# 28             12445
# 29             12442

# %% [markdown]
# #### How many customers do we have in Spain?

# %%
# your code here

print("Spain customer qty: ", spain['CustomerID'].unique().size)
# Out:
# Spain customer qty:  30

# %% [markdown]
# #### Select all the customers who have bought more than 50 items.
# **Hint**: Remember that you are not asked to find orders with more than 50 items but customers who bought more than 50 items. A customer with two orders of 30 items each should appear in the selection.

# %%
# your code here


more50items_df = (orders_df.groupby(['CustomerID']).agg({'Quantity':'sum'}).reset_index())
more50items_df = (more50items_df[more50items_df['Quantity'] > 50])
pd.DataFrame(more50items_df['CustomerID'].unique(),columns=['Cust bought > 50 items'])
# Out:
#       Cust bought > 50 items
# 0                      12346
# 1                      12347
# 2                      12348
# 3                      12349
# 4                      12350
# ...                      ...
# 4086                   18278
# 4087                   18281
# 4088                   18282
# 4089                   18283
# 4090                   18287
#
# [4091 rows x 1 columns]

# %% [markdown]
# #### Select orders from Spain that include more than 50 items.

# %%
# your code here

spainmore50items_df = (spain.groupby(['InvoiceNo']).agg({'Quantity':'sum'}).reset_index())
spainmore50items_df = (spainmore50items_df[spainmore50items_df['Quantity'] > 50])
pd.DataFrame(spainmore50items_df['InvoiceNo'].unique(), columns=['Orders > 50 items'])
# Out:
#     Orders > 50 items
# 0              536944
# 1              538095
# 2              538525
# 3              539351
# 4              540469
# ..                ...
# 75             578321
# 76             578339
# 77             579503
# 78             580955
# 79             581193
#
# [80 rows x 1 columns]

# %% [markdown]
# #### Select all free orders.

# %%
# your code here

freeorders = (orders_df[orders_df['amount_spent'] == 0]).reset_index() 
pd.DataFrame(freeorders['InvoiceNo'].unique(), columns=['Free Orders'])
# Out:
#     Free Orders
# 0        537197
# 1        539263
# 2        539722
# 3        540372
# 4        541109
# 5        543599
# 6        547417
# 7        548318
# 8        548871
# 9        550188
# 10       553000
# 11       554037
# 12       561284
# 13       561669
# 14       561916
# 15       562973
# 16       564651
# 17       568158
# 18       568384
# 19       569716
# 20       571035
# 21       572893
# 22       574138
# 23       574175
# 24       574252
# 25       574469
# 26       574879
# 27       574920
# 28       575579
# 29       577129
# 30       577168
# 31       577314
# 32       577696
# 33       578841

# %% [markdown]
# #### Select all orders whose description starts with `lunch bag`.
# **Hint**: use string functions.

# %%
# your code here

lunchbag_df = orders_df[orders_df['Description'].str.contains("lunch bag")]
pd.DataFrame(lunchbag_df['InvoiceNo'].unique(), columns=['Orders w/"lunch bag"'])
# Out:
#       Orders w/"lunch bag"
# 0                   536378
# 1                   536385
# 2                   536401
# 3                   536404
# 4                   536412
# ...                    ...
# 3460                581474
# 3461                581486
# 3462                581538
# 3463                581581
# 3464                581583
#
# [3465 rows x 1 columns]

# %% [markdown]
# #### Select all `lunch bag` orders made in 2011.

# %%
# your code here

lunchbag_df_2011 = (lunchbag_df[lunchbag_df['year'] == 2011])
pd.DataFrame(lunchbag_df_2011['InvoiceNo'].unique(), columns=['2011 Orders w/"lunch bag"'])
# Out:
#       2011 Orders w/"lunch bag"
# 0                        540015
# 1                        540023
# 2                        540098
# 3                        540099
# 4                        540157
# ...                         ...
# 3342                     581474
# 3343                     581486
# 3344                     581538
# 3345                     581581
# 3346                     581583
#
# [3347 rows x 1 columns]

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your code here

orders_df['amount_spent'].value_counts().plot(x ='Value', y='Freq', kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Select all orders made in the month of August.

# %%
# your code here

august_orders = (orders_df[orders_df['month'] == 8])
pd.DataFrame(august_orders['InvoiceNo'].unique(), columns=['August Orders'])
# Out:
#       August Orders
# 0            561904
# 1            561905
# 2            561906
# 3            561907
# 4            561908
# ...             ...
# 1276         564976
# 1277         564995
# 1278         565014
# 1279         565056
# 1280         565067
#
# [1281 rows x 1 columns]

# %% [markdown]
# #### Find the number of orders made by each country in the month of August.
# **Hint**: Use value_counts().

# %%
# your code here

pd.DataFrame(august_orders.groupby(['Country']).agg({'InvoiceNo':'nunique'}).reset_index())
# Out:
#             Country  InvoiceNo
# 0         Australia          2
# 1           Austria          2
# 2           Belgium          9
# 3            Canada          1
# 4   Channel Islands          5
# 5           Denmark          1
# 6              EIRE         17
# 7           Finland          3
# 8            France         28
# 9           Germany         39
# 10          Iceland          1
# 11           Israel          1
# 12            Italy          4
# 13            Malta          2
# 14      Netherlands          8
# 15           Norway          2
# 16           Poland          2
# 17         Portugal          1
# 18            Spain         10
# 19           Sweden          5
# 20      Switzerland          3
# 21   United Kingdom       1133
# 22      Unspecified          2

# %% [markdown]
# #### What's the  average amount of money spent by country?

# %%
# your code here

pd.DataFrame(orders_df.groupby(['Country']).agg({'amount_spent':'mean'}).reset_index())
# Out:
#                  Country  amount_spent
# 0              Australia    116.895620
# 1                Austria     25.624824
# 2                Bahrain     32.258824
# 3                Belgium     20.283772
# 4                 Brazil     35.737500
# 5                 Canada     24.280662
# 6        Channel Islands     27.340160
# 7                 Cyprus     22.134169
# 8         Czech Republic     33.069600
# 9                Denmark     49.882474
# 10                  EIRE     36.687745
# 11    European Community     21.670833
# 12               Finland     32.913985
# 13                France     25.056827
# 14               Germany     25.311562
# 15                Greece     32.831172
# 16               Iceland     23.681319
# 17                Israel     29.119718
# 18                 Italy     23.064960
# 19                 Japan    116.561900
# 20               Lebanon     37.641778
# 21             Lithuania     47.458857
# 22                 Malta     24.335625
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your code here

(orders_df.loc[orders_df['UnitPrice'] == (orders_df['UnitPrice'].max()), ('Description','StockCode','UnitPrice')].iloc[0])
# Out:
# Description    postage
# StockCode         POST
# UnitPrice      8142.75
# Name: 118352, dtype: object

# %% [markdown]
# #### What is the average amount spent per year?

# %%
# your code here

pd.DataFrame(orders_df.groupby(['year']).agg({'amount_spent':'mean'}).reset_index())
# Out:
#    year  amount_spent
# 0  2010     21.892733
# 1  2011     22.430074
