# %% [markdown]
# # Subsetting and Descriptive Stats
#
# ## Before your start:
#    - Remember that you just need to do one of the challenges.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in IronHack's database.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly: enjoy the process!
#
# #### Import all the necessary libraries here:

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # [ONLY ONE MANDATORY] Challenge 1
# #### In this challenge we will use the `Temp_States`  dataset.
#
# #### First import it into a dataframe called `temp`.

# %%
# your code here

temp = pd.read_csv('Temp_States.csv')
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Print `temp`.

# %%
# your code here
print(temp)
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the *temp* dataframe. What types of data do we have? Comment your result.

# %%
# your code here
temp.dtypes
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %%
"""
your comments here

City and State are objetct types. Temperature is float 
"""
# Out:
# '\nyour comments here\n\nCity and State are objetct types. Temperature is float \n'

# %% [markdown]
# #### Select the rows where state is New York.

# %%
# your code here

temp[temp['State']=='New York']
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average temperature of cities in New York?

# %%
# your code here
temp[temp['State']=='New York']['Temperature'].mean()
# Out:
# 10.74074074074074

# %% [markdown]
# #### Which states and cities have a temperature above 15 degrees Celsius?

# %%
# your code here
temp[(temp['Temperature']>=14) & (temp['Temperature']<=16) ][['State', 'City']]
# Out:
#          State        City
# 4  Connecticut  Bridgeport

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degrees Celsius.

# %%
# your code here
temp[(temp['Temperature']>=14) & (temp['Temperature']<=16) ]['City']
# Out:
# 4    Bridgeport
# Name: City, dtype: object

# %% [markdown]
# #### Which cities have a temperature above 15 degrees Celcius and below 20 degrees Celsius?
#
# **Hint**: First, write the condition. Then, select the rows.

# %%
# your code here
temp[(temp['Temperature']>=14) & (temp['Temperature']<=20) ]['City']
# Out:
# 0           NYC
# 3      Hartford
# 4    Bridgeport
# 6        Newark
# Name: City, dtype: object

# %% [markdown]
# #### Find the mean and standard deviation of the temperature of each state.

# %%
# your code here
st = np.std(temp['Temperature'])
mn = np.mean(temp['Temperature'])
print('Mean:',mn)
print('Standard deviation:',st)
# Out:
# Mean: 15.158730158730156
# Standard deviation: 6.198610853894169

# %% [markdown]
# # [ONLY ONE MANDATORY]  Challenge 2

# %% [markdown]
# #### Load the `employees` dataset into a dataframe. Call the dataframe `employees`.

# %%
# your code here
employees = pd.read_csv('Employee.csv')
employees
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Explore the data types of the `employees` dataframe. Comment your results.

# %%
# your code here
employees.dtypes
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %%
"""
your comments here
Object type: Name, Department, Education, Gender, Title
Integrer type: Years, Salary
"""
# Out:
# '\nyour comments here\nObject type: Name, Department, Education, Gender, Title\nIntegrer type: Years, Salary\n'

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your code here
np.mean(employees['Salary'])
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
# your code here
employees['Salary'].max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
# your code here
employees['Salary'].min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your code here
employees[employees['Salary'] == employees['Salary'].min()]['Name']
# Out:
# 1    Maria
# 2    David
# Name: Name, dtype: object

# %% [markdown]
# #### Find all the information about an employee called David.

# %%
# your code here
employees[employees['Name']=='David']
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you return only David's salary?

# %%
# your code here
employees[employees['Name']=='David']['Salary']
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate.

# %%
# your code here
employees[employees['Title']=='associate']
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe.
# **Tip**: There are 2 ways to do it. Do it both ways.

# %%
# Method 1
# your code here
employees.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# Method 2
# your code here
employees[:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees whose title is associate and whose salary is above 55.

# %%
# your code here
employees[(employees['Title']=='associate')& ((employees['Salary']>52) & (employees['Salary']<57))]
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55

# %% [markdown]
# #### Group the employees by number of years of employment. What are the average salaries in each group?

# %%
# your code here
employees.groupby(['Years']).agg({'Salary':'mean'}).reset_index().head()
# Out:
#    Years     Salary
# 0      1  35.000000
# 1      2  38.333333
# 2      3  55.000000
# 3      4  35.000000
# 4      7  60.000000

# %% [markdown]
# ####  What is the average salary per title?

# %%
# your code here
employees.groupby(['Title']).agg({'Salary':'mean'}).reset_index().head()
# Out:
#        Title     Salary
# 0         VP  70.000000
# 1    analyst  32.500000
# 2  associate  56.666667

# %% [markdown]
# ####  Find the salary quartiles.

# %%
# your code here

salary_list = employees['Salary']
#Para usar numpy, debo pasar un array
q_1 = np.percentile(salary_list, 25)
q_2 = np.percentile(salary_list, 50)
q_3 = np.percentile(salary_list, 75)
print('First quartile:', q_1,'Second quartile:', q_2, 'Third quartile:', q_3)
# Out:
# First quartile: 35.0 Second quartile: 55.0 Third quartile: 60.0

# %% [markdown]
# #### Is the mean salary different per gender?

# %%
# your code here
employees.groupby(['Gender']).agg({'Salary':'mean'}).reset_index().head()
# Out:
#   Gender  Salary
# 0      F    47.5
# 1      M    50.0

# %% [markdown]
# #### Find the minimum, mean and maximum of all numeric columns for each company department.

# %%
# your code here
mean_values = employees.groupby(['Department']).agg({'Years':'mean','Salary':'mean'})
max_values = employees.groupby(['Department']).agg({'Years':'max','Salary':'max'})
min_values = employees.groupby(['Department']).agg({'Years':'min','Salary':'min'})

mean_values = mean_values.rename(columns={'Years': 'Mean_Years', 'Salary': 'Mean_Salary'})
mean_values
max_values = mean_values.rename(columns={'Years': 'Max_Years', 'Salary': 'Max_Salary'})
max_values
min_values = mean_values.rename(columns={'Years': 'Min_Years', 'Salary': 'Min_Salary'})
min_values
print(mean_values)
print(max_values)
print(min_values)
# Out:
#             Mean_Years  Mean_Salary
# Department
# HR            4.666667        45.00
# IT            4.500000        48.75
# Sales         2.500000        55.00
#             Mean_Years  Mean_Salary
# Department
# HR            4.666667        45.00
# IT            4.500000        48.75
# Sales         2.500000        55.00
#             Mean_Years  Mean_Salary
# Department
# HR            4.666667        45.00
# IT            4.500000        48.75
# Sales         2.500000        55.00

# %% [markdown]
# #### Bonus Question:  for each department, compute the difference between the maximum and the minimum salary.
# **Hint**: try using `agg` or `apply` combined with `lambda` functions.

# %%
# your code here
HR_dif = employees[employees['Department']=='HR']['Salary'].max()-employees[employees['Department']=='HR']['Salary'].min()
IT_dif = employees[employees['Department']=='IT']['Salary'].max()-employees[employees['Department']=='IT']['Salary'].min()
Sales_dif = employees[employees['Department']=='Sales']['Salary'].max()-employees[employees['Department']=='Sales']['Salary'].min()

print('HR:', HR_dif,'IT:',IT_dif, 'Sales:', Sales_dif)
# Out:
# HR: 40 IT: 40 Sales: 0

# %% [markdown]
# # [ONLY ONE MANDATORY] Challenge 3
# #### Open the `Orders` dataset. Name your dataset `orders`.

# %%
# your code here
orders = pd.read_csv('Orders.csv')
orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0                0     536365    85123A  2010     12    3     8
# 1                1     536365     71053  2010     12    3     8
# 2                2     536365    84406B  2010     12    3     8
# 3                3     536365    84029G  2010     12    3     8
# 4                4     536365    84029E  2010     12    3     8
# ...            ...        ...       ...   ...    ...  ...   ...
# 397919      541904     581587     22613  2011     12    5    12
# 397920      541905     581587     22899  2011     12    5    12
# 397921      541906     581587     23254  2011     12    5    12
# 397922      541907     581587     23255  2011     12    5    12
# 397923      541908     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6  2010-12-01 08:26:00
# ...

# %% [markdown]
# #### Explore your dataset by looking at the data types and summary statistics. Comment your results.

# %%
# your code here
orders.dtypes

orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %%
"""
your comments here
Int:InvoiceNo, year,month,day,hour,Quantity, CustomerID
Float:UnitPrice, amount_spent
Objet: StockCode,Description,InvoiceDate, Country

numerical relationship: amount_spent = quantity*unitprice
categorical columns:InvoiceNo, year,month,day,hour,CustomerID,StockCode,Description,InvoiceDate, Country

stats:
quantity, unit_price, amount_spent -> high standar deviation 
"""
# Out:
# '\nyour comments here\nInt:InvoiceNo, year,month,day,hour,Quantity, CustomerID\nFloat:UnitPrice, amount_spent\nObjet: StockCode,Description,InvoiceDate, Country\n\nnumerical relationship: amount_spent = quantity*unitprice\ncategorical columns:InvoiceNo, year,month,day,hour,CustomerID,StockCode,Description,InvoiceDate, Country\n\nstats:\nquantity, unit_price, amount_spent -> high standar deviation \n'

# %% [markdown]
# ####  What is the average purchase price?

# %%
# your code here
orders['UnitPrice'].mean()
# Out:
# 3.116174480549152

# %% [markdown]
# #### What are the highest and lowest purchase prices?

# %%
# your code here
print('Min and max unit price:', orders['UnitPrice'].min(),orders['UnitPrice'].max())
print('Min and max spent amount:', orders['amount_spent'].min(),orders['amount_spent'].max())
# Out:
# Min and max unit price: 0.0 8142.75
# Min and max spent amount: 0.0 168469.6

# %% [markdown]
# #### Select all the customers from Spain.
# **Hint**: Remember that you are not asked to find orders from Spain but customers. A customer might have more than one order associated.

# %%
# your code here
orders[orders['Country'] == 'Spain']['CustomerID']
# Out:
# 4250      12557
# 4251      12557
# 4252      12557
# 4253      12557
# 4254      12557
#           ...
# 394733    17097
# 394734    17097
# 394735    17097
# 394736    17097
# 394737    17097
# Name: CustomerID, Length: 2485, dtype: int64

# %% [markdown]
# #### How many customers do we have in Spain?

# %%
# your code here
orders[orders['Country'] == 'Spain']['CustomerID'].count()
# Out:
# 2485

# %% [markdown]
# #### Select all the customers who have bought more than 50 items.
# **Hint**: Remember that you are not asked to find orders with more than 50 items but customers who bought more than 50 items. A customer with two orders of 30 items each should appear in the selection.

# %%
# your code here
orders[orders['amount_spent'] >= 50]['CustomerID']
# Out:
# 9         13047
# 26        12583
# 27        12583
# 33        12583
# 34        12583
#           ...
# 397881    13777
# 397882    13777
# 397883    13777
# 397907    13113
# 397908    13113
# Name: CustomerID, Length: 27233, dtype: int64

# %% [markdown]
# #### Select orders from Spain that include more than 50 items.

# %%
# your code here
orders[(orders['Country'] == 'Spain')& (orders['Quantity']>=50)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 32454        52416     540785    84997B  2011      1    2    11
# 32455        52417     540785    84997D  2011      1    2    11
# 32456        52418     540785    84997C  2011      1    2    11
# 32457        52419     540785    84997A  2011      1    2    11
# 91155       136767     547972     22383  2011      3    1    16
# 91156       136768     547972     22384  2011      3    1    16
# 91157       136769     547972     20727  2011      3    1    16
# 91158       136770     547972     20725  2011      3    1    16
# 91159       136771     547972     20728  2011      3    1    16
# ...

# %% [markdown]
# #### Select all free orders.

# %%
# your code here
orders[orders['amount_spent']==0]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders whose description starts with `lunch bag`.
# **Hint**: use string functions.

# %%
# your code here
orders[orders['Description'].str.contains('lunch bag')]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# ...

# %% [markdown]
# #### Select all `lunch bag` orders made in 2011.

# %%
# your code here
orders[(orders['Description'].str.contains('lunch bag'))&(orders['year']==2011)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340        42678     540015     20725  2011      1    2    11
# 26341        42679     540015     20726  2011      1    2    11
# 26512        42851     540023     22382  2011      1    2    12
# 26513        42852     540023     20726  2011      1    2    12
# 26860        43616     540098     22384  2011      1    2    15
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your code here
# 


frequency_distribution = orders['amount_spent'].value_counts()
print(frequency_distribution)


frequency_distribution.plot(kind='bar', color='skyblue')

# Personalizar el gráfico.
plt.title('Freq of amount_spent')
plt.xlabel('Values')
plt.ylabel('Frecuency')
plt.xticks(rotation=0)  

# Mostrar el gráfico.
plt.show()
# Out:
# 15.00     20082
# 19.80     11033
# 17.70      9174
# 16.50      8490
# 10.20      8028
#           ...
# 176.28        1
# 61.95         1
# 17.73         1
# 308.89        1
# 77.50         1
# Name: amount_spent, Length: 2811, dtype: int64

# %% [markdown]
# #### Select all orders made in the month of August.

# %%
# your code here
orders[orders['month']==8]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 226483      320688     565067     22644  2011      8    3    17
# 226484      320689     565067     22645  2011      8    3    17
# 226485      320690     565067     22637  2011      8    3    17
# 226486      320691     565067     22646  2011      8    3    17
# 226487      320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 199475         6 ribbons elegant christmas         96  2011-08-01 08:30:00
# ...

# %% [markdown]
# #### Find the number of orders made by each country in the month of August.
# **Hint**: Use value_counts().

# %%
# your code here
orders[orders['month']==8].groupby(['Country']).agg({'InvoiceNo':'count'})
# Out:
#                  InvoiceNo
# Country
# Australia              107
# Austria                 88
# Belgium                194
# Canada                   5
# Channel Islands        140
# Denmark                 16
# EIRE                   593
# Finland                 61
# France                 569
# Germany                795
# Iceland                 22
# Israel                 171
# Italy                   95
# Malta                   55
# Netherlands            280
# Norway                  77
# Poland                  17
# Portugal                41
# Spain                  252
# Sweden                  40
# Switzerland            267
# United Kingdom       23105
# Unspecified             23

# %% [markdown]
# #### What's the  average amount of money spent by country?

# %%
# your code here
orders.groupby(['Country']).agg({'amount_spent':'mean'})
# Out:
#                       amount_spent
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your code here
#orders[orders['UnitPrice']==(orders[orders['Description']!='postage']['UnitPrice'].max())]['Description']
orders[orders['UnitPrice']==orders['UnitPrice'].max()]['Description']

#como lo mas caro son los envios y no es un item como tal, debemos mirar los items que no sean envios:
orders[orders['UnitPrice']==(orders[orders['Description']!='postage']['UnitPrice'].max())]['Description']
# Out:
# 308822    manual
# 308846    manual
# Name: Description, dtype: object

# %% [markdown]
# #### What is the average amount spent per year?

# %%
# your code here
orders.groupby(['year']).agg({'amount_spent':'mean'})
# Out:
#       amount_spent
# year
# 2010     21.892733
# 2011     22.430074
